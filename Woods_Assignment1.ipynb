# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import statistics
# %pushd "/content/drive/MyDrive/MSSP6070/Assignments/Assignment01/"
# Out:
# /content/drive/MyDrive/MSSP6070/Assignments/Assignment01
# ['/content/drive/My Drive/MSSP6070/Assignments/Assignment01',
#  '/content/drive/My Drive/MSSP6070/Assignments/Assignment01',
#  '/content',
#  '/content']

# %%
# Loading in data
df = pd.read_csv('Student Performance Data.csv')

df.columns.tolist()
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'math score',
#  'reading score',
#  'writing score',
#  'total score',
#  'test preparation course',
#  'admission prospect']

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#    math score  reading score  writing score  total score  \
# 0          72             72             74          218
# 1          69             90             88          247
# 2          90             95             93          278
# 3          47             57             44          148
# 4          76             78             75          229
#
#   test preparation course admission prospect
# 0                    none             medium
# 1               completed               high
# 2                    none               high
# ...

# %% [markdown]
# Reordering two variables to make output easier to read later.

# %%
new_order = ["some high school", "high school", "some college", "associate's degree", "bachelor's degree", "master's degree"]
df['parental level of education'] = pd.Categorical(df['parental level of education'], categories=new_order, ordered=True)
df = df.sort_values(by='parental level of education')

# %%
new_order2 = ["low", "medium", "high"]
df['admission prospect'] = pd.Categorical(df['admission prospect'], categories=new_order2, ordered=True)
df = df.sort_values(by='admission prospect')

# %% [markdown]
# Getting descriptive statistics to copy over to an excel spreadsheet.
#
# ---

# %%
df['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
df['race/ethnicity'].value_counts(normalize=True)
# Out:
# group C    0.319
# group D    0.262
# group B    0.190
# group E    0.140
# group A    0.089
# Name: race/ethnicity, dtype: float64

# %%
df['parental level of education'].value_counts(normalize=True)
# Out:
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64

# %%
df['lunch'].value_counts(normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
df['test preparation course'].value_counts(normalize=True)
# Out:
# none         0.642
# completed    0.358
# Name: test preparation course, dtype: float64

# %%
df['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
df['admission prospect'].value_counts(normalize=True)
# Out:
# medium    0.475
# high      0.356
# low       0.169
# Name: admission prospect, dtype: float64

# %%
df.describe()
# Out:
#        math score  reading score  writing score  total score
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000
# std      15.16308      14.600192      15.195657    42.771978
# min       0.00000      17.000000      10.000000    27.000000
# 25%      57.00000      59.000000      57.750000   175.000000
# 50%      66.00000      70.000000      69.000000   205.000000
# 75%      77.00000      79.000000      79.000000   233.000000
# max     100.00000     100.000000     100.000000   300.000000

# %% [markdown]
# Getting descriptive statistics by test preparation course completion.
#
# ---

# %%
pd.crosstab(df["test preparation course"], df["gender"], normalize="index")
# Out:
# gender                     female      male
# test preparation course
# completed                0.513966  0.486034
# none                     0.520249  0.479751

# %%
pd.crosstab(df["test preparation course"], df["race/ethnicity"], normalize="index")
# Out:
# race/ethnicity            group A   group B   group C   group D   group E
# test preparation course
# completed                0.086592  0.189944  0.326816  0.229050  0.167598
# none                     0.090343  0.190031  0.314642  0.280374  0.124611

# %%
pd.crosstab(df["test preparation course"], df["lunch"], normalize="index")
# Out:
# lunch                    free/reduced  standard
# test preparation course
# completed                    0.365922  0.634078
# none                         0.348910  0.651090

# %%
pd.crosstab(df["test preparation course"], df["parental level of education"], normalize="index")
# Out:
# parental level of education  some high school  high school  some college  \
# test preparation course
# completed                            0.215084     0.156425      0.215084
# none                                 0.158879     0.218069      0.232087
#
# parental level of education  associate's degree  bachelor's degree  \
# test preparation course
# completed                              0.229050           0.128492
# none                                   0.218069           0.112150
#
# parental level of education  master's degree
# test preparation course
# completed                           0.055866
# none                                0.060748

# %% [markdown]
# Looking at Admissions Prospects

# %%
pd.crosstab(df["test preparation course"], df["admission prospect"], normalize="index")
# Out:
# admission prospect            low    medium      high
# test preparation course
# completed                0.083799  0.407821  0.508380
# none                     0.216511  0.512461  0.271028

# %%
df.groupby("test preparation course").mean()
# Out:
# <ipython-input-75-44cd30436ed4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("test preparation course").mean()
#                          math score  reading score  writing score  total score
# test preparation course
# completed                 69.695531      73.893855      74.418994   218.008380
# none                      64.077882      66.534268      64.504673   195.116822

# %% [markdown]
# Looking at Parental Education Level
#
# ---

# %%
df.groupby(['parental level of education'])["total score", 'math score', 'reading score', 'writing score'].mean()
# Out:
# <ipython-input-76-5e9b2d0350e3>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['parental level of education'])["total score", 'math score', 'reading score', 'writing score'].mean()
#                              total score  math score  reading score  \
# parental level of education
# some high school              195.324022   63.497207      66.938547
# high school                   189.290816   62.137755      64.704082
# some college                  205.429204   67.128319      69.460177
# associate's degree            208.707207   67.882883      70.927928
# bachelor's degree             215.771186   69.389831      73.000000
# master's degree               220.796610   69.745763      75.372881
#
#                              writing score
# parental level of education
# some high school                 64.888268
# high school                      62.448980
# ...

# %%
df.groupby(['parental level of education', "test preparation course"])["total score", 'math score', 'reading score', 'writing score'].mean()
# Out:
# <ipython-input-77-1f05065b57b9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['parental level of education', "test preparation course"])["total score", 'math score', 'reading score', 'writing score'].mean()
#                                                      total score  math score  \
# parental level of education test preparation course
# some high school            completed                 208.012987   66.701299
#                             none                      185.745098   61.078431
# high school                 completed                 200.892857   65.000000
#                             none                      184.650000   60.992857
# some college                completed                 223.961039   71.454545
#                             none                      195.852349   64.892617
# associate's degree          completed                 224.817073   71.829268
# ...

# %%
pd.crosstab(df["parental level of education"], df["admission prospect"], normalize="index")
# Out:
# admission prospect                low    medium      high
# parental level of education
# some high school             0.229050  0.446927  0.324022
# high school                  0.239796  0.545918  0.214286
# some college                 0.137168  0.482301  0.380531
# associate's degree           0.148649  0.454955  0.396396
# bachelor's degree            0.084746  0.457627  0.457627
# master's degree              0.118644  0.406780  0.474576

# %%
pd.crosstab(df["admission prospect"], df["parental level of education"], normalize="index")
# Out:
# parental level of education  some high school  high school  some college  \
# admission prospect
# low                                  0.242604     0.278107      0.183432
# medium                               0.168421     0.225263      0.229474
# high                                 0.162921     0.117978      0.241573
#
# parental level of education  associate's degree  bachelor's degree  \
# admission prospect
# low                                    0.195266           0.059172
# medium                                 0.212632           0.113684
# high                                   0.247191           0.151685
#
# parental level of education  master's degree
# admission prospect
# low                                 0.041420
# medium                              0.050526
# high                                0.078652

# %% [markdown]
# Looking at Gender
#
# ---

# %%
df.groupby(['gender'])["total score", 'math score', 'reading score', 'writing score'].mean()
# Out:
# <ipython-input-80-e6320be58701>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['gender'])["total score", 'math score', 'reading score', 'writing score'].mean()
#         total score  math score  reading score  writing score
# gender
# female   208.708494   63.633205      72.608108      72.467181
# male     197.512448   68.728216      65.473029      63.311203

# %%
df.groupby(['gender', 'test preparation course'])["total score", 'math score', 'reading score', 'writing score'].mean()
# Out:
# <ipython-input-81-7b9775e365bd>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['gender', 'test preparation course'])["total score", 'math score', 'reading score', 'writing score'].mean()
#                                 total score  math score  reading score  \
# gender test preparation course
# female completed                 223.364130   67.195652      77.375000
#        none                      200.634731   61.670659      69.982036
# male   completed                 212.344828   72.339080      70.212644
#        none                      189.133117   66.688312      62.795455
#
#                                 writing score
# gender test preparation course
# female completed                    78.793478
#        none                         68.982036
# male   completed                    69.793103
#        none                         59.649351

# %%
pd.crosstab(df["gender"], df["admission prospect"], normalize="index")
# Out:
# admission prospect       low    medium      high
# gender
# female              0.137066  0.457529  0.405405
# male                0.203320  0.493776  0.302905

# %%
pd.crosstab(df["admission prospect"], df["gender"], normalize="index")
# Out:
# gender                female      male
# admission prospect
# low                 0.420118  0.579882
# medium              0.498947  0.501053
# high                0.589888  0.410112

# %%
df.groupby(["admission prospect"])[ "gender" ].value_counts(normalize=True).reset_index(name='counts')
# Out:
#   admission prospect  gender    counts
# 0                low    male  0.579882
# 1                low  female  0.420118
# 2             medium    male  0.501053
# 3             medium  female  0.498947
# 4               high  female  0.589888
# 5               high    male  0.410112

# %% [markdown]
# Looking at Race/Ethnicity

# %%
df.groupby(['race/ethnicity'])["total score", 'math score', 'reading score', 'writing score'].mean()
# Out:
# <ipython-input-85-d01f6b296406>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['race/ethnicity'])["total score", 'math score', 'reading score', 'writing score'].mean()
#                 total score  math score  reading score  writing score
# race/ethnicity
# group A          188.977528   61.629213      64.674157      62.674157
# group B          196.405263   63.452632      67.352632      65.600000
# group C          201.394984   64.463950      69.103448      67.827586
# group D          207.538168   67.362595      70.030534      70.145038
# group E          218.257143   73.821429      73.028571      71.407143

# %%
df.groupby(["race/ethnicity", "test preparation course"])["total score", 'math score', 'reading score', 'writing score'].mean().reset_index()
# Out:
# <ipython-input-86-802cc1727794>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["race/ethnicity", "test preparation course"])["total score", 'math score', 'reading score', 'writing score'].mean().reset_index()
#   race/ethnicity test preparation course  total score  math score  \
# 0        group A               completed   210.193548   68.258065
# 1        group A                    none   177.637931   58.086207
# 2        group B               completed   211.926471   67.191176
# 3        group B                    none   187.754098   61.368852
# 4        group C               completed   215.606838   67.495726
# 5        group C                    none   193.163366   62.707921
# 6        group D               completed   220.597561   69.792683
# 7        group D                    none   201.588889   66.255556
# 8        group E               completed   230.083333   77.433333
# ...

# %%
pd.crosstab(df["race/ethnicity"], df["admission prospect"], normalize="index")
# Out:
# admission prospect       low    medium      high
# race/ethnicity
# group A             0.303371  0.460674  0.235955
# group B             0.210526  0.468421  0.321053
# group C             0.153605  0.520376  0.326019
# group D             0.133588  0.480916  0.385496
# group E             0.128571  0.378571  0.492857

# %%
df.groupby(["race/ethnicity"])["admission prospect" ].value_counts(normalize=True).reset_index(name='counts')
# Out:
#    race/ethnicity admission prospect    counts
# 0         group A             medium  0.460674
# 1         group A                low  0.303371
# 2         group A               high  0.235955
# 3         group B             medium  0.468421
# 4         group B               high  0.321053
# 5         group B                low  0.210526
# 6         group C             medium  0.520376
# 7         group C               high  0.326019
# 8         group C                low  0.153605
# 9         group D             medium  0.480916
# 10        group D               high  0.385496
# 11        group D                low  0.133588
# 12        group E               high  0.492857
# 13        group E             medium  0.378571
# 14        group E                low  0.128571

# %%
df.groupby(["admission prospect"])[ "race/ethnicity" ].value_counts(normalize=True).reset_index(name='counts')
# Out:
#    admission prospect race/ethnicity    counts
# 0                 low        group C  0.289941
# 1                 low        group B  0.236686
# 2                 low        group D  0.207101
# 3                 low        group A  0.159763
# 4                 low        group E  0.106509
# 5              medium        group C  0.349474
# 6              medium        group D  0.265263
# 7              medium        group B  0.187368
# 8              medium        group E  0.111579
# 9              medium        group A  0.086316
# 10               high        group C  0.292135
# 11               high        group D  0.283708
# 12               high        group E  0.193820
# 13               high        group B  0.171348
# 14               high        group A  0.058989

# %%
df.groupby(["race/ethnicity", 'gender', 'test preparation course'])['total score'].mean()
# Out:
# race/ethnicity  gender  test preparation course
# group A         female  completed                  221.333333
#                         none                       182.416667
#                 male    completed                  203.157895
#                         none                       174.264706
# group B         female  completed                  211.628571
#                         none                       197.913043
#                 male    completed                  212.242424
#                         none                       174.528302
# group C         female  completed                  222.246377
#                         none                       195.504505
#                 male    completed                  206.062500
#                         none                       190.307692
# group D         female  completed                  225.522727
#                         none                       208.517647
# ...
